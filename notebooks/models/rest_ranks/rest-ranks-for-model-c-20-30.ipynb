# %%
import pandas as pd
import numpy as np

from tqdm import tqdm

from collections import Counter

import gc
import cloudpickle

import os, sys
import random

import warnings

import xgboost as xgb

print('Using \033[34mXGBoost', xgb.__version__, '\033[0m')
# Out:
# Using XGBoost 1.5.0

# %% [markdown]
# ## Inference

# %%
pd.set_option('display.max_colwidth', None)

# %%
ranker = xgb.sklearn.XGBRanker()
ranker.load_model('../input/semi-playground-ranking-model-c-20-30/ranker-00.model')

# %%
test_images = pd.read_csv('../input/final-image-traindataset-part0-4-count-5/final_images.csv')
test_images['image_id'] = test_images.index
matchings = pd.read_csv('../input/combiner-target-dataset-0-of-5/final_matchings.csv')
test_images
# Out:
#                                                                                                                                                                                                              image_url  \
# 0                                                                                                                         http://upload.wikimedia.org/wikipedia/commons/0/00/Apoxyomenos_Pio-Clementino_Inv1185_n2.jpg
# 1                                                                                                                                http://upload.wikimedia.org/wikipedia/commons/0/00/Babybox_-_venkovn%C3%AD_strana.jpg
# 2                                                                                                                                        http://upload.wikimedia.org/wikipedia/commons/0/00/Betania_royal_portrait.jpg
# 3                                                                                                                                           http://upload.wikimedia.org/wikipedia/commons/0/00/BlochGlassHarmonica.jpg
# 4                                                                                                                                          http://upload.wikimedia.org/wikipedia/commons/0/00/BolivianChilePowder2.JPG
# ...                                                                                                                                                                                                                ...
# 69475                                                                                                                    https://upload.wikimedia.org/wikipedia/ja/c/c3/The_five_professors_of_Tokyo_Bible_Semiary.jpg
# 69476                                                                                                                https://upload.wikimedia.org/wikipedia/ru/7/7b/%D0%9A%D1%83%D0%BD%D1%86%D0%B5%D0%B2%D0%BE1940.jpg
# 69477  https://upload.wikimedia.org/wikipedia/ru/9/95/%D0%9A%D0%BE%D0%BC%D0%B0%D0%BD%D0%B4%D0%B8%D1%80%D1%8B%D0%9F%D0%B5%D1%80%D0%B2%D0%BE%D0%B9%D0%9A%D0%BE%D0%BD%D0%BD%D0%BE%D0%B9%D0%B0%D1%80%D0%BC%D0%B8%D0%B8.jpg
# 69478                                                                                                                                                 https://upload.wikimedia.org/wikipedia/ru/c/cb/Politburo1934.jpg
# 69479                                                                                                                                             https://upload.wikimedia.org/wikipedia/vi/0/0f/NamKy6tinh-Taberd.jpg
#
#        count                                    filename  \
# 0          4       Apoxyomenos Pio-Clementino Inv1185 n2
# 1          4                   Babybox - venkovní strana
# 2          4                      Betania royal portrait
# 3          5                         BlochGlassHarmonica
# 4          4                        BolivianChilePowder2
# ...      ...                                         ...
# 69475      4  The five professors of Tokyo Bible Semiary
# 69476      4                                 Кунцево1940
# 69477      4                  КомандирыПервойКоннойармии
# 69478      4                               Politburo1934
# 69479      4                           NamKy6tinh-Taberd
#
#                                    pured_filename  \
# 0           Apoxyomenos Pio Clementino Inv1185 n2
# 1                         Babybox venkovní strana
# 2                          Betania royal portrait
# 3                             BlochGlassHarmonica
# 4                            BolivianChilePowder2
# ...                                           ...
# 69475  The five professors of Tokyo Bible Semiary
# 69476                                 Кунцево1940
# 69477                  КомандирыПервойКоннойармии
# 69478                               Politburo1934
# 69479                           NamKy6tinh Taberd
#
#                                   spaced_filename  \
# 0         Apoxyomenos Pio Clementino Inv 1185 n 2
# 1                         Babybox venkovní strana
# 2                          Betania royal portrait
# 3                           Bloch Glass Harmonica
# 4                         Bolivian Chile Powder 2
# ...                                           ...
# 69475  The five professors of Tokyo Bible Semiary
# 69476                                Кунцево 1940
# 69477                Командиры Первой Коннойармии
# 69478                              Politburo 1934
# 69479                        Nam Ky 6 tinh Taberd
#
#                                  undigit_filename filename_lang  filename_en  \
# 0                Apoxyomenos Pio Clementino Inv n            en         True
# 1                         Babybox venkovní strana            cs        False
# 2                          Betania royal portrait            en         True
# 3                           Bloch Glass Harmonica            en         True
# 4                           Bolivian Chile Powder            en         True
# ...                                           ...           ...          ...
# 69475  The five professors of Tokyo Bible Semiary            en         True
# 69476                                     Кунцево            ru        False
# 69477                Командиры Первой Коннойармии            ru        False
# 69478                                   Politburo            fr        False
# 69479                          Nam Ky tinh Taberd            vi        False
#
#        section      spaced_filename_translit  ext  filename_contains_digit  \
# 0      commons                           NaN  jpg                     True
# 1      commons       Babybox venkovni strana  unk                    False
# 2      commons                           NaN  jpg                    False
# 3      commons                           NaN  jpg                    False
# 4      commons                           NaN  jpg                     True
# ...        ...                           ...  ...                      ...
# 69475       ja                           NaN  jpg                    False
# 69476       ru                 Kuntsevo 1940  jpg                     True
# 69477       ru  Komandiry Pervoj Konnojarmii  jpg                    False
# 69478       ru                           NaN  jpg                     True
# 69479       vi                           NaN  jpg                     True
#
#           id undigit_filename_translation  \
# 0          0                          NaN
# 1          1        Babybox outdoor party
# 2          2                          NaN
# 3          3                          NaN
# 4          4                          NaN
# ...      ...                          ...
# 69475  69475                          NaN
# 69476  69476                     Kuntsevo
# 69477  69477     First Cavalry Commanders
# 69478  69478                    Politburo
# 69479  69479       Southern Planet Taberd
#
#                                    final_filename  \
# 0                Apoxyomenos Pio Clementino Inv n
# 1                           Babybox outdoor party
# 2                          Betania royal portrait
# 3                           Bloch Glass Harmonica
# 4                           Bolivian Chile Powder
# ...                                           ...
# 69475  The five professors of Tokyo Bible Semiary
# 69476                                    Kuntsevo
# 69477                    First Cavalry Commanders
# 69478                                   Politburo
# 69479                      Southern Planet Taberd
#
#                                 PREfinal_filename  \
# 0                Apoxyomenos Pio Clementino Inv n
# 1                           Babybox outdoor party
# 2                          Betania royal portrait
# 3                           Bloch Glass Harmonica
# 4                           Bolivian Chile Powder
# ...                                           ...
# 69475  The five professors of Tokyo Bible Semiary
# 69476                                    Kuntsevo
# 69477                    First Cavalry Commanders
# 69478                                   Politburo
# 69479                      Southern Planet Taberd
#
#                           spaced_undigit_filename  image_id
# 0                Apoxyomenos Pio Clementino Inv n         0
# 1                         Babybox venkovní strana         1
# 2                          Betania royal portrait         2
# 3                           Bloch Glass Harmonica         3
# 4                           Bolivian Chile Powder         4
# ...                                           ...       ...
# 69475  The five professors of Tokyo Bible Semiary     69475
# 69476                                     Кунцево     69476
# 69477                Командиры Первой Коннойармии     69477
# 69478                                   Politburo     69478
# 69479                          Nam Ky tinh Taberd     69479
#
# [69480 rows x 18 columns]

# %%
def pre_competition_inference(ranker, X, image_ids, target_ids):
    rank_pred = ranker.predict(X)
    
    answer = pd.DataFrame({ 'image_id': image_ids, 'target_id': target_ids, 'rank': rank_pred })

    answer.sort_values(by=['image_id', 'rank'], inplace=True, kind='mergesort', ascending=False)
    
    result = answer.groupby('image_id').head(50)
    
    temp = matchings[['target_id', 'target']]
    result = pd.merge(result, temp, on='target_id')

    temp = test_images[['image_id', 'count', 'undigit_filename', 'image_url']]
    result = pd.merge(result, temp, on='image_id')
    result.sort_values(by=['image_id', 'rank'], kind='mergesort', ascending=False, inplace=True)
    
    result['hyperref'] = result['image_url']
    
    return result, answer


def make_clickable(val):
    return '<a target="_blank" href="{}">click</a>'.format(val)

# %%
columns2float16 = ['CAPITAL_RANK', 'CAPTION_SENSE_CAPITAL_RANK_3', 'TITLE_SENSE_CAPITAL_RANK_3', 'CAPTION_SENSE_CAPITAL_RANK_3_mean-std', 'TITLE_SENSE_CAPITAL_RANK_3_mean-std',
    'WEAK_ENTITY_RANK', 'TITLE_VISUAL_WEAK_ENTITY_RANK_3', 'TITLE_SENSE_WEAK_ENTITY_RANK_3', 'TITLE_VISUAL_WEAK_ENTITY_RANK_3_mean-std', 'CAPTION_VISUAL_WEAK_ENTITY_RANK_3',
    'TITLE_SENSE_WEAK_ENTITY_RANK_3_mean-std', 'XTITLE_WEAK_ENTITY_RANK', 'CAPTION_VISUAL_WEAK_ENTITY_RANK_3_mean-std', 'CAPTION_SENSE_WEAK_ENTITY_RANK_3',
    'CAPITAL_ACRONYM_RANK', 'CRUDE_ACRONYM_RANK', 'FUZZY_TITLE_RANK', 'XCAPTION_WEAK_ENTITY_RANK', 'CAPTION_SENSE_WEAK_ENTITY_RANK_3_mean-std',
    'VISUAL_UNDIGIT_CAPTION', 'VISUAL_UNDIGIT_TITLE', 'VISUAL_FINAL_CAPTION', 'VISUAL_FINAL_TITLE', 'CAPTION_VISUAL_AGGR', 'TITLE_VISUAL_AGGR',
    'SENSE_UNDIGIT_FILENAME_UNDIGIT_TITLE',
    'SENSE_FINAL_FILENAME_UNDIGIT_TITLE',
    'TITLE_SENSE_AGGR',
    'SENSE_UNDIGIT_FILENAME_FINAL_TITLE',
    'SENSE_FINAL_FILENAME_FINAL_TITLE',
    'FUZZY_CAPTION_RANK',
    'TITLE_VISUAL_FUZZY_TITLE_RANK_3',
    'SENSE_UNDIGIT_FILENAME_UNDIGIT_CAPTION',
    'SENSE_FINAL_FILENAME_UNDIGIT_CAPTION',
    'TITLE_VISUAL_TITLE_CROSS_FUZZY_RANK_3',
    'TITLE_VISUAL_FUZZY_CAPTION_RANK_3',
    'TITLE_CROSS_FUZZY_RANK',
    'CAPTION_SENSE_AGGR',
    'SENSE_UNDIGIT_FILENAME_FINAL_CAPTION',
    'TITLE_VISUAL_FUZZY_TITLE_RANK_3_mean-std',
    'SENSE_FINAL_FILENAME_FINAL_CAPTION',
    'TITLE_VISUAL_CRUDE_ACRONYM_RANK_3',
    'TITLE_VISUAL_FUZZY_CAPTION_RANK_3_mean-std',
    'TITLE_VISUAL_CAPTION_CROSS_FUZZY_RANK_3',
    'CAPTION_VISUAL_FUZZY_TITLE_RANK_3',
    'TITLE_SENSE_FUZZY_TITLE_RANK_3',
    'TITLE_VISUAL_CRUDE_ACRONYM_RANK_3_mean-std',
    'TITLE_VISUAL_CAPITAL_ACRONYM_RANK_3_mean-std',
    'TITLE_VISUAL_CAPITAL_ACRONYM_RANK_3',
    'TITLE_SENSE_FUZZY_CAPTION_RANK_3',
    'TITLE_VISUAL_TITLE_CROSS_FUZZY_RANK_3_mean-std',
    'CAPTION_VISUAL_TITLE_CROSS_FUZZY_RANK_3',
    'TITLE_SENSE_CAPTION_CROSS_FUZZY_RANK_3',
    'TITLE_VISUAL_NUMERIC_RANK_3',
    'CAPTION_CROSS_FUZZY_RANK',
    'TITLE_SENSE_TITLE_CROSS_FUZZY_RANK_3']


def compress(X):
    for c, dtype in X.dtypes.iteritems():
        if dtype == np.float64:
            X[c] = X[c].astype(np.float32)
        
        if c.startswith('DCAPTION') or c.startswith('DTITLE') or c.startswith('DFILENAME') or c.startswith('DIMG'):
            X[c] = X[c].astype(np.float16)
            
    for c in columns2float16:
        X[c] = X[c].astype(np.float16)
            
    X.fillna(-1000., inplace=True)
    
    _ = X
    X = _.copy()
    del _
    gc.collect()
    
    return X

# %%
# %%time


import os

results = []

parts = ['../input/mining-for-ranking-model-c-00-10/valid-70', '../input/mining-for-ranking-model-c-00-10/valid-71', \
    '../input/mining-for-ranking-model-c-50-60/train-09', '../input/mining-for-ranking-model-c-60-70/train-09']

for k, part in enumerate(parts):

    X = pd.read_parquet(os.path.join(part, 'features.parquet'))
    y = pd.read_parquet(os.path.join(part, 'targets.parquet')).iloc[:, 0].values
    
    with open(os.path.join(part, 'group.pickle'), 'rb') as file:
        group = cloudpickle.load(file)
        
    
    image_ids = pd.read_parquet(os.path.join(part, 'image_ids.parquet')).iloc[:, 0].values
    target_ids = pd.read_parquet(os.path.join(part, 'target_ids.parquet')).iloc[:, 0].values


    X = compress(X)
    r, answer = pre_competition_inference(ranker, X, image_ids, target_ids)
    
    answer.to_csv('ranks-{}.csv'.format(k), index=False)
    
    r.to_csv('short-ranks-{}.csv'.format(k), index=False)
    
    results.append(r)
    
    del X
    del y
    del group
    del image_ids
    del target_ids
    
    gc.collect()
# Out:
# CPU times: user 23min 57s, sys: 38 s, total: 24min 35s
# Wall time: 8min 10s

# %%
answer
# Out:
#          image_id  target_id       rank
# 3120718     69458      51661   6.386174
# 3120886     69458      73940   5.306353
# 3120888     69458      73942   3.598258
# 3120716     69458      51659   2.359045
# 3121116     69458     102282   1.844517
# ...           ...        ...        ...
# 2902           52     280594 -16.017820
# 1780           52     166973 -16.023342
# 34             52       3373 -16.056675
# 1949           52     186569 -16.062426
# 1              52        149 -16.431192
#
# [3122614 rows x 3 columns]

# %%
r.iloc[0:10].style.format({'hyperref': make_clickable}).hide_columns(['image_url'])
# Out:
# <style type="text/css">
# </style>
# <table id="T_33403_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >image_id</th>
#       <th class="col_heading level0 col1" >target_id</th>
#       <th class="col_heading level0 col2" >rank</th>
#       <th class="col_heading level0 col3" >target</th>
#       <th class="col_heading level0 col4" >count</th>
#       <th class="col_heading level0 col5" >undigit_filename</th>
#       <th class="col_heading level0 col7" >hyperref</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_33403_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_33403_row0_col0" class="data row0 col0" >69458</td>
#       <td id="T_33403_row0_col1" class="data row0 col1" >51661</td>
#       <td id="T_33403_row0_col2" class="data row0 col2" >6.386174</td>
#       <td id="T_33403_row0_col3" class="data row0 col3" >Hellboy – Call of Darkness [SEP] Die Kathedrale von Wells in der Grafschaft Somerset im Südwesten Englands</td>
#       <td id="T_33403_row0_col4" class="data row0 col4" >4</td>
#       <td id="T_33403_row0_col5" class="data row0 col5" >Wells Cathedral West Front Exterior UK Diliff</td>
#       <td id="T_33403_row0_col7" class="data row0 col7" ><a target="_blank" href="https://upload.wikimedia.org/wikipedia/commons/f/ff/Wells_Cathedral_West_Front_Exterior%2C_UK_-_Diliff.jpg">click</a></td>
#     </tr>
#     <tr>
#       <th id="T_33403_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_33403_row1_col0" class="data row1 col0" >69458</td>
#       <td id="T_33403_row1_col1" class="data row1 col1" >73940</td>
#       <td id="T_33403_row1_col2" class="data row1 col2" >5.306353</td>
#       <td id="T_33403_row1_col3" class="data row1 col3" >Bisbat antic de Bath i Wells [SEP] La catedral de Wells.</td>
#       <td id="T_33403_row1_col4" class="data row1 col4" >4</td>
#       <td id="T_33403_row1_col5" class="data row1 col5" >Wells Cathedral West Front Exterior UK Diliff</td>
#       <td id="T_33403_row1_col7" class="data row1 col7" ><a target="_blank" href="https://upload.wikimedia.org/wikipedia/commons/f/ff/Wells_Cathedral_West_Front_Exterior%2C_UK_-_Diliff.jpg">click</a></td>
#     </tr>
#     <tr>
#       <th id="T_33403_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_33403_row2_col0" class="data row2 col0" >69458</td>
#       <td id="T_33403_row2_col1" class="data row2 col1" >73942</td>
#       <td id="T_33403_row2_col2" class="data row2 col2" >3.598258</td>
#       <td id="T_33403_row2_col3" class="data row2 col3" >Diözese Bath und Wells [SEP] Kathedrale in Wells</td>
#       <td id="T_33403_row2_col4" class="data row2 col4" >4</td>
#       <td id="T_33403_row2_col5" class="data row2 col5" >Wells Cathedral West Front Exterior UK Diliff</td>
#       <td id="T_33403_row2_col7" class="data row2 col7" ><a target="_blank" href="https://upload.wikimedia.org/wikipedia/commons/f/ff/Wells_Cathedral_West_Front_Exterior%2C_UK_-_Diliff.jpg">click</a></td>
#     </tr>
#     <tr>
#       <th id="T_33403_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_33403_row3_col0" class="data row3 col0" >69458</td>
#       <td id="T_33403_row3_col1" class="data row3 col1" >51659</td>
#       <td id="T_33403_row3_col2" class="data row3 col2" >2.359045</td>
#       <td id="T_33403_row3_col3" class="data row3 col3" >Keuskupan Bath dan Wells (Katolik Roma) [SEP] Katedral Wells</td>
#       <td id="T_33403_row3_col4" class="data row3 col4" >4</td>
#       <td id="T_33403_row3_col5" class="data row3 col5" >Wells Cathedral West Front Exterior UK Diliff</td>
#       <td id="T_33403_row3_col7" class="data row3 col7" ><a target="_blank" href="https://upload.wikimedia.org/wikipedia/commons/f/ff/Wells_Cathedral_West_Front_Exterior%2C_UK_-_Diliff.jpg">click</a></td>
#     </tr>
#     <tr>
#       <th id="T_33403_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_33403_row4_col0" class="data row4 col0" >69458</td>
#       <td id="T_33403_row4_col1" class="data row4 col1" >102282</td>
#       <td id="T_33403_row4_col2" class="data row4 col2" >1.844517</td>
#       <td id="T_33403_row4_col3" class="data row4 col3" >춤 [SEP] 잉글랜드 웰스 지방의 웰스 대성당(Wells Cathedral) 정원에서 추는 모리스 춤(Morris dancing)</td>
#       <td id="T_33403_row4_col4" class="data row4 col4" >4</td>
#       <td id="T_33403_row4_col5" class="data row4 col5" >Wells Cathedral West Front Exterior UK Diliff</td>
#       <td id="T_33403_row4_col7" class="data row4 col7" ><a target="_blank" href="https://upload.wikimedia.org/wikipedia/commons/f/ff/Wells_Cathedral_West_Front_Exterior%2C_UK_-_Diliff.jpg">click</a></td>
#     </tr>
#     <tr>
#       <th id="T_33403_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_33403_row5_col0" class="data row5 col0" >69458</td>
#       <td id="T_33403_row5_col1" class="data row5 col1" >25793</td>
#       <td id="T_33403_row5_col2" class="data row5 col2" >1.300557</td>
#       <td id="T_33403_row5_col3" class="data row5 col3" >Exeter [SEP] Exeterin katedraali</td>
#       <td id="T_33403_row5_col4" class="data row5 col4" >4</td>
#       <td id="T_33403_row5_col5" class="data row5 col5" >Wells Cathedral West Front Exterior UK Diliff</td>
#       <td id="T_33403_row5_col7" class="data row5 col7" ><a target="_blank" href="https://upload.wikimedia.org/wikipedia/commons/f/ff/Wells_Cathedral_West_Front_Exterior%2C_UK_-_Diliff.jpg">click</a></td>
#     </tr>
#     <tr>
#       <th id="T_33403_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_33403_row6_col0" class="data row6 col0" >69458</td>
#       <td id="T_33403_row6_col1" class="data row6 col1" >25794</td>
#       <td id="T_33403_row6_col2" class="data row6 col2" >1.279336</td>
#       <td id="T_33403_row6_col3" class="data row6 col3" >Kathedrale St. Peter (Exeter) [SEP] Exeter Cathedral</td>
#       <td id="T_33403_row6_col4" class="data row6 col4" >4</td>
#       <td id="T_33403_row6_col5" class="data row6 col5" >Wells Cathedral West Front Exterior UK Diliff</td>
#       <td id="T_33403_row6_col7" class="data row6 col7" ><a target="_blank" href="https://upload.wikimedia.org/wikipedia/commons/f/ff/Wells_Cathedral_West_Front_Exterior%2C_UK_-_Diliff.jpg">click</a></td>
#     </tr>
#     <tr>
#       <th id="T_33403_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_33403_row7_col0" class="data row7 col0" >69458</td>
#       <td id="T_33403_row7_col1" class="data row7 col1" >171609</td>
#       <td id="T_33403_row7_col2" class="data row7 col2" >1.119109</td>
#       <td id="T_33403_row7_col3" class="data row7 col3" >Katedrála Panny Marie (Girona) [SEP] Severní fasáda: vlevo patrný nižší podkovovitý závěr s fiálami opěrných pilířů, více vpravo přiléhá těsně k lodi jen o málo vyšší románská věž s dvojicemi podvojných oken v každém podlaží, patrné jsou rovněž mohutné opěrné pilíře lodi</td>
#       <td id="T_33403_row7_col4" class="data row7 col4" >4</td>
#       <td id="T_33403_row7_col5" class="data row7 col5" >Wells Cathedral West Front Exterior UK Diliff</td>
#       <td id="T_33403_row7_col7" class="data row7 col7" ><a target="_blank" href="https://upload.wikimedia.org/wikipedia/commons/f/ff/Wells_Cathedral_West_Front_Exterior%2C_UK_-_Diliff.jpg">click</a></td>
#     </tr>
#     <tr>
#       <th id="T_33403_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_33403_row8_col0" class="data row8 col0" >69458</td>
#       <td id="T_33403_row8_col1" class="data row8 col1" >25796</td>
#       <td id="T_33403_row8_col2" class="data row8 col2" >0.675350</td>
#       <td id="T_33403_row8_col3" class="data row8 col3" >Exeter Cathedral [SEP] The side of the cathedral</td>
#       <td id="T_33403_row8_col4" class="data row8 col4" >4</td>
#       <td id="T_33403_row8_col5" class="data row8 col5" >Wells Cathedral West Front Exterior UK Diliff</td>
#       <td id="T_33403_row8_col7" class="data row8 col7" ><a target="_blank" href="https://upload.wikimedia.org/wikipedia/commons/f/ff/Wells_Cathedral_West_Front_Exterior%2C_UK_-_Diliff.jpg">click</a></td>
#     </tr>
#     <tr>
#       <th id="T_33403_leve
