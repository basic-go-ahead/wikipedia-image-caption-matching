# %%
import os

import numpy as np
import pandas as pd

import cloudpickle

from transformers import *
import torch
# Out:
# 2021-11-08 21:32:22.502547: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/lib
# 2021-11-08 21:32:22.502668: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# /opt/conda/lib/python3.7/site-packages/torchaudio/backend/utils.py:54: UserWarning: "sox" backend is being deprecated. The default backend will be changed to "sox_io" backend in 0.8.0 and "sox" backend will be removed in 0.9.0. Please migrate to "sox_io" backend. Please refer to https://github.com/pytorch/audio/issues/903 for the detail.
#   '"sox" backend is being deprecated. '

# %%
matchings = pd.read_csv('../input/combiner-target-dataset-0-of-5/final_matchings.csv', keep_default_na=False)

print(matchings.shape)

matchings.head(3)
# Out:
# (301664, 26)
#                                            image_url    page_title  \
# 0  https://upload.wikimedia.org/wikipedia/commons...  Jürgen Ovens
# 1  https://upload.wikimedia.org/wikipedia/commons...  Jürgen Ovens
# 2  https://upload.wikimedia.org/wikipedia/commons...  Овенс, Юрген
#
#                        caption_reference_description  count  \
# 0  Jürgen Ovens's Justitia, 1663-1665, Museumsber...      4
# 1  Jürgen Ovens: Justitia, 1663-1665, Museumsberg...      4
# 2  Юрген Овенс Юстиция, 1663—1665, Музей Фленсбур...      4
#
#          spaced_filename spaced_filename_translit page_title_translit  \
# 0  Jurgen ovens justitia                                Juergen Ovens
# 1  Jurgen ovens justitia                                Juergen Ovens
# 2  Jurgen ovens justitia                                Ovens, Jurgen
#
#                                     caption_translit page_title_lang  \
# 0  Juergen Ovens's Justitia, 1663-1665, Museumsbe...              en
# 1  Juergen Ovens: Justitia, 1663-1665, Museumsber...              en
# 2  Jurgen Ovens Justitsija, 1663—1665, Muzej Flen...              ru
#
#    page_title_lang_p  ...  page_title_contains_digit undigit_page_title  \
# 0           0.124504  ...                      False       Jürgen Ovens
# 1           0.124504  ...                      False       Jürgen Ovens
# 2           0.647271  ...                      False       Овенс, Юрген
#
#                                               target  target_id  \
# 0  Jürgen Ovens [SEP] Jürgen Ovens's Justitia, 16...          0
# 1  Jürgen Ovens [SEP] Jürgen Ovens: Justitia, \n ...          1
# 2  Овенс, Юрген [SEP] Юрген Овенс Юстиция, 1663—1...          2
#
#                                  caption_translation  \
# 0
# 1
# 2  Jurgen Owens Justice, -, Flensburg Museum. Owe...
#
#                                        final_caption  \
# 0  Jürgen Ovens's Justitia, 1663-1665, Museumsber...
# 1  Jürgen Ovens: Justitia, 1663-1665, Museumsberg...
# 2  Jurgen Owens Justice, -, Flensburg Museum. Owe...
#
#                                     PREfinal_caption page_title_translation  \
# 0  Jürgen Ovens's Justitia, 1663-1665, Museumsber...
# 1  Jürgen Ovens: Justitia, 1663-1665, Museumsberg...
# 2  Jurgen Owens Justice, -, Flensburg Museum. Owe...          Owens, Jürgen
#
#   final_page_title  PREfinal_page_title
# 0     Jürgen Ovens         Jürgen Ovens
# 1     Jürgen Ovens         Jürgen Ovens
# 2    Owens, Jürgen        Owens, Jürgen
#
# [3 rows x 26 columns]

# %%
matchings = matchings[matchings['page_title_lang'].isin(['en', 'de', 'it', 'fr'])]

matchings
# Out:
#                                                 image_url  \
# 0       https://upload.wikimedia.org/wikipedia/commons...
# 1       https://upload.wikimedia.org/wikipedia/commons...
# 3       https://upload.wikimedia.org/wikipedia/commons...
# 5       https://upload.wikimedia.org/wikipedia/commons...
# 8       https://upload.wikimedia.org/wikipedia/commons...
# ...                                                   ...
# 301659  https://upload.wikimedia.org/wikipedia/commons...
# 301660  https://upload.wikimedia.org/wikipedia/commons...
# 301661  https://upload.wikimedia.org/wikipedia/commons...
# 301662  https://upload.wikimedia.org/wikipedia/commons...
# 301663  https://upload.wikimedia.org/wikipedia/commons...
#
#                                  page_title  \
# 0                              Jürgen Ovens
# 1                              Jürgen Ovens
# 3                              Jürgen Ovens
# 5                             November 1970
# 8                               Nigersaurus
# ...                                     ...
# 301659              National Gallery Prague
# 301660          San Diego Convention Center
# 301661          San Diego Convention Center
# 301662  1996 Republican National Convention
# 301663  1996 Republican National Convention
#
#                             caption_reference_description  count  \
# 0       Jürgen Ovens's Justitia, 1663-1665, Museumsber...      4
# 1       Jürgen Ovens: Justitia, 1663-1665, Museumsberg...      4
# 3       Justitia aus Schloss Gottorf, um 1665, Museums...      4
# 5                                                 Amalrik      4
# 8          Model af hovedet på Australian Museum, Sydney.      4
# ...                                                   ...    ...
# 301659  Veletržní palác (the Trade Fair Palace) houses...      4
# 301660          View of the center from the San Diego Bay      4
# 301661          View of the center from the San Diego Bay      4
# 301662  The San Diego Convention Center was the site o...      4
# 301663  The San Diego Convention Center was the site o...      4
#
#                     spaced_filename   spaced_filename_translit  \
# 0             Jurgen ovens justitia
# 1             Jurgen ovens justitia
# 3             Jurgen ovens justitia
# 5               Andrei Amalrik 1976
# 8             Nigersaurus model aus
# ...                             ...                        ...
# 301659    Praha Veletržní palác jih  Praha Veletržni palac jih
# 301660  San Diego Convention Center
# 301661  San Diego Convention Center
# 301662  San Diego Convention Center
# 301663  San Diego Convention Center
#
#        page_title_translit                                   caption_translit  \
# 0            Juergen Ovens  Juergen Ovens's Justitia, 1663-1665, Museumsbe...
# 1            Juergen Ovens  Juergen Ovens: Justitia, 1663-1665, Museumsber...
# 3            Juergen Ovens
# 5
# 8                             Model af hovedet paa Australian Museum, Sydney.
# ...                    ...                                                ...
# 301659                      Veletržni palac (the Trade Fair Palace) houses...
# 301660
# 301661
# 301662
# 301663
#
#        page_title_lang  page_title_lang_p  ...  page_title_contains_digit  \
# 0                   en           0.124504  ...                      False
# 1                   en           0.124504  ...                      False
# 3                   en           0.124504  ...                      False
# 5                   en           0.969909  ...                       True
# 8                   en           0.124504  ...                      False
# ...                ...                ...  ...                        ...
# 301659              en           0.686658  ...                      False
# 301660              en           0.576476  ...                      False
# 301661              en           0.576476  ...                      False
# 301662              en           0.748757  ...                       True
# 301663              en           0.748757  ...                       True
#
#                      undigit_page_title  \
# 0                          Jürgen Ovens
# 1                          Jürgen Ovens
# 3                          Jürgen Ovens
# 5                             November
# 8                           Nigersaurus
# ...                                 ...
# 301659          National Gallery Prague
# 301660      San Diego Convention Center
# 301661      San Diego Convention Center
# 301662   Republican National Convention
# 301663   Republican National Convention
#
#                                                    target  target_id  \
# 0       Jürgen Ovens [SEP] Jürgen Ovens's Justitia, 16...          0
# 1       Jürgen Ovens [SEP] Jürgen Ovens: Justitia, \n ...          1
# 3       Jürgen Ovens [SEP] Justitia aus Schloss Gottor...          3
# 5                             November 1970 [SEP] Amalrik          5
# 8       Nigersaurus [SEP] Model af hovedet på Australi...          8
# ...                                                   ...        ...
# 301659  National Gallery Prague [SEP] Veletržní palác ...     301659
# 301660  San Diego Convention Center [SEP] View of the ...     301660
# 301661  San Diego Convention Center [SEP] View of the ...     301661
# 301662  1996 Republican National Convention [SEP] The ...     301662
# 301663  1996 Republican National Convention [SEP] The ...     301663
#
#                                       caption_translation  \
# 0
# 1
# 3       Justitia from Gottorf Castle, um, Museumsberg ...
# 5
# 8       Model of the head at the Australian Museum, Sy...
# ...                                                   ...
# 301659
# 301660
# 301661
# 301662
# 301663
#
#                                             final_caption  \
# 0       Jürgen Ovens's Justitia, 1663-1665, Museumsber...
# 1       Jürgen Ovens: Justitia, 1663-1665, Museumsberg...
# 3       Justitia from Gottorf Castle, um, Museumsberg ...
# 5                                                 Amalrik
# 8       Model of the head at the Australian Museum, Sy...
# ...                                                   ...
# 301659  Veletržní palác (the Trade Fair Palace) houses...
# 301660          View of the center from the San Diego Bay
# 301661          View of the center from the San Diego Bay
# 301662  The San Diego Convention Center was the site o...
# 301663  The San Diego Convention Center was the site o...
#
#                                          PREfinal_caption  \
# 0       Jürgen Ovens's Justitia, 1663-1665, Museumsber...
# 1       Jürgen Ovens: Justitia, 1663-1665, Museumsberg...
# 3       Justitia from Gottorf Castle, um, Museumsberg ...
# 5                                                 Amalrik
# 8       Model of the head at the Australian Museum, Sy...
# ...                                                   ...
# 301659  Veletržní palác (the Trade Fair Palace) houses...
# 301660          View of the center from the San Diego Bay
# 301661          View of the center from the San Diego Bay
# 301662  The San Diego Convention Center was the site o...
# 301663  The San Diego Convention Center was the site o...
#
#        page_title_translation                     final_page_title  \
# 0                                                     Jürgen Ovens
# 1                                                     Jürgen Ovens
# 3                                                     Jürgen Ovens
# 5                                                    November 1970
# 8                                                      Nigersaurus
# ...                       ...                                  ...
# 301659                                     National Gallery Prague
# 301660                                 San Diego Convention Center
# 301661                                 San Diego Convention Center
# 301662                         1996 Republican National Convention
# 301663                         1996 Republican National Convention
#
#                         PREfinal_page_title
# 0                              Jürgen Ovens
# 1                              Jürgen Ovens
# 3                              Jürgen Ovens
# 5                             November 1970
# 8                               Nigersaurus
# ...                                     ...
# 301659              National Gallery Prague
# 301660          San Diego Convention Center
# 301661          San Diego Convention Center
# 301662  1996 Republican National Convention
# 301663  1996 Republican National Convention
#
# [134887 rows x 26 columns]

# %%
model = AutoModelForTokenClassification.from_pretrained("dbmdz/bert-large-cased-finetuned-conll03-english")
tokenizer = AutoTokenizer.from_pretrained("bert-base-cased")

label_list = [
    "O",       # Outside of a named entity
    "B-MISC",  # Beginning of a miscellaneous entity right after another miscellaneous entity
    "I-MISC",  # Miscellaneous entity
    "B-PER",   # Beginning of a person's name right after another person's name
    "I-PER",   # Person's name
    "B-ORG",   # Beginning of an organisation right after another organisation
    "I-ORG",   # Organisation
    "B-LOC",   # Beginning of a location right after another location
    "I-LOC"    # Location
]
# Out:
# Downloading:   0%|          | 0.00/998 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/213k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/436k [00:00<?, ?B/s]

# %%
def retrieve_entities(pairs, verbose=False):
    def repair(s):
        return s.replace(' #', '').replace('#', '')
    def unique(l):
        return list(set(l))
    
    
    reading_entity = False
    current_entity_type = None
    
    misc, per, org, loc = [], [], [], []
    
    entity_parts = []
    
    for part, et in pairs:
        if not reading_entity and et == 'O':
            continue
        else:
            if not reading_entity:
                current_et = et
                reading_entity = True               
                
            if current_et == et:
                entity_parts.append(part)
            else:
                repaired_entity = repair(' '.join(entity_parts))
                
                if verbose:
                    print(repaired_entity)
                    
                locals()[current_et.split('-')[-1].lower()].append(repaired_entity)
                entity_parts.clear()
                
                if et == 'O':
                    reading_entity = False
                    current_et = None
                else:
                    entity_parts.append(part)
                    current_et = 'I-' + et.split('-')[-1]
                    
                    
    return { 'misc': unique(misc), 'per': unique(per), 'org': unique(org), 'loc': unique(loc)}

# %%
image_entities = { }

for index, row in matchings.iterrows():
    try:
        sequence = row['page_title'].strip()
        
        if sequence != '':
            tokens = tokenizer.tokenize(tokenizer.decode(tokenizer.encode(sequence)))
            inputs = tokenizer.encode(sequence, return_tensors="pt")

            outputs = model(inputs)[0]
            predictions = torch.argmax(outputs, dim=2)

            l = [(token, label_list[prediction]) for token, prediction in zip(tokens, predictions[0].tolist())]

            image_entities[index] = retrieve_entities(l)
    except Exception as ex:
        print(index, sequence)
        print(str(ex))
        print()

# %%
with open('page_title_lang_entities.dump', 'wb') as file:
    cloudpickle.dump(image_entities, file)
