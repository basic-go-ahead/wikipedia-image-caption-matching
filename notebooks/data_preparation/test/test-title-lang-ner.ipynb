# %%
import os

import numpy as np
import pandas as pd

import cloudpickle

from transformers import *
import torch
# Out:
# 2021-11-26 20:21:29.922029: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/lib
# 2021-11-26 20:21:29.922161: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# /opt/conda/lib/python3.7/site-packages/torchaudio/backend/utils.py:54: UserWarning: "sox" backend is being deprecated. The default backend will be changed to "sox_io" backend in 0.8.0 and "sox" backend will be removed in 0.9.0. Please migrate to "sox_io" backend. Please refer to https://github.com/pytorch/audio/issues/903 for the detail.
#   '"sox" backend is being deprecated. '

# %%
matchings = pd.read_csv('../input/test-combiner-target-dataset/final_matchings.csv', keep_default_na=False)

print(matchings.shape)

matchings.head(3)
# Out:
# (92366, 22)
#     page_title                caption_reference_description  \
# 0  Albert Pike                                  Albert Pike
# 1  Anna Blount  Blount and her young daughter Ruth, in 1911
# 2  Río Marañón  Die Río Marañón in die Huánuco-streek, Peru
#
#   page_title_translit                             caption_translit  \
# 0
# 1
# 2         Rio Maranon  Die Rio Maranon in die Huanuco-streek, Peru
#
#   page_title_lang  page_title_lang_p  page_title_en caption_lang  \
# 0              en           0.124504           True           en
# 1              en           0.739186           True           en
# 2              es           0.684134          False           de
#
#    caption_lang_p  caption_en  ...  page_title_contains_digit  \
# 0        0.124504        True  ...                      False
# 1        0.971129        True  ...                      False
# 2        0.376005       False  ...                      False
#
#   undigit_page_title                                             target  \
# 0        Albert Pike                      Albert Pike [SEP] Albert Pike
# 1        Anna Blount  Anna Blount [SEP] Blount and her young daughte...
# 2        Río Marañón  Río Marañón [SEP] Die Río Marañón in die Huánu...
#
#   target_id                          caption_translation  \
# 0         0
# 1         1
# 2         2  Die Río Marañón in die Huánuco-streek, Peru
#
#                                  final_caption  \
# 0                                  Albert Pike
# 1  Blount and her young daughter Ruth, in 1911
# 2  Die Río Marañón in die Huánuco-streek, Peru
#
#                               PREfinal_caption page_title_translation  \
# 0                                  Albert Pike
# 1  Blount and her young daughter Ruth, in 1911
# 2  Die Río Marañón in die Huánuco-streek, Peru          Marañón River
#
#   final_page_title PREfinal_page_title
# 0      Albert Pike         Albert Pike
# 1      Anna Blount         Anna Blount
# 2    Marañón River       Marañón River
#
# [3 rows x 22 columns]

# %%
matchings = matchings[matchings['page_title_lang'].isin(['en', 'de', 'it', 'fr'])]

matchings
# Out:
#                               page_title  \
# 0                            Albert Pike
# 1                            Anna Blount
# 3                         Leonel Brizola
# 4                             Buttisholz
# 7      St. Louis Cathedral (New Orleans)
# ...                                  ...
# 92354     Magistrates' court (Hong Kong)
# 92355              Haida Heritage Centre
# 92359                          Zicartola
# 92361                      Essen (Haren)
# 92362                  Mindszenty József
#
#                            caption_reference_description page_title_translit  \
# 0                                            Albert Pike
# 1            Blount and her young daughter Ruth, in 1911
# 3      Brizola during his inauguration ceremony as go...
# 4                                             Buttisholz
# 7                St. Louis Cathedral, Innenansicht, 2007
# ...                                                  ...                 ...
# 92354                       Kwun Tong Magistrates' Court
# 92355              Haida Heritage Centre at Kay Llnagaay
# 92359                    Clara Nunes no Zicartola, 1971.
# 92361                                              Essen
# 92362        Boldog IV. Károly és felesége Zita királyné   Mindszenty Jozsef
#
#                                   caption_translit page_title_lang  \
# 0                                                               en
# 1                                                               en
# 3                                                               en
# 4                                                               en
# 7                                                               en
# ...                                            ...             ...
# 92354                                                           en
# 92355                                                           en
# 92359                                                           en
# 92361                                                           en
# 92362  Boldog IV. Karoly es felesege Zita kiralyne              de
#
#        page_title_lang_p  page_title_en caption_lang  caption_lang_p  \
# 0               0.124504           True           en        0.124504
# 1               0.739186           True           en        0.971129
# 3               0.361589           True           en        0.997266
# 4               0.346513           True           en        0.346513
# 7               0.632638           True           de        0.494620
# ...                  ...            ...          ...             ...
# 92354           0.823363           True           en        0.692984
# 92355           0.639575           True           en        0.821923
# 92359           0.236621           True           en        0.578084
# 92361           0.290392           True           en        0.124504
# 92362           0.358293          False           hu        0.987040
#
#        caption_en  ...  page_title_contains_digit  \
# 0            True  ...                      False
# 1            True  ...                      False
# 3            True  ...                      False
# 4            True  ...                      False
# 7           False  ...                      False
# ...           ...  ...                        ...
# 92354        True  ...                      False
# 92355        True  ...                      False
# 92359        True  ...                      False
# 92361        True  ...                      False
# 92362       False  ...                      False
#
#                       undigit_page_title  \
# 0                            Albert Pike
# 1                            Anna Blount
# 3                         Leonel Brizola
# 4                             Buttisholz
# 7      St. Louis Cathedral (New Orleans)
# ...                                  ...
# 92354     Magistrates' court (Hong Kong)
# 92355              Haida Heritage Centre
# 92359                          Zicartola
# 92361                      Essen (Haren)
# 92362                  Mindszenty József
#
#                                                   target target_id  \
# 0                          Albert Pike [SEP] Albert Pike         0
# 1      Anna Blount [SEP] Blount and her young daughte...         1
# 3      Leonel Brizola [SEP] Brizola during his inaugu...         3
# 4                            Buttisholz [SEP] Buttisholz         4
# 7      St. Louis Cathedral (New Orleans) [SEP] St. Lo...         7
# ...                                                  ...       ...
# 92354  Magistrates' court (Hong Kong) [SEP] Kwun Tong...     92354
# 92355  Haida Heritage Centre [SEP] Haida Heritage Cen...     92355
# 92359    Zicartola [SEP] Clara Nunes no Zicartola, 1971.     92359
# 92361                          Essen (Haren) [SEP] Essen     92361
# 92362  Mindszenty József [SEP] Boldog IV. Károly és f...     92362
#
#                              caption_translation  \
# 0
# 1
# 3
# 4
# 7            St. Louis Cathedral, Interior view,
# ...                                          ...
# 92354
# 92355
# 92359
# 92361
# 92362  Happy IV. Charles and his wife Queen Zita
#
#                                            final_caption  \
# 0                                            Albert Pike
# 1            Blount and her young daughter Ruth, in 1911
# 3      Brizola during his inauguration ceremony as go...
# 4                                             Buttisholz
# 7                    St. Louis Cathedral, Interior view,
# ...                                                  ...
# 92354                       Kwun Tong Magistrates' Court
# 92355              Haida Heritage Centre at Kay Llnagaay
# 92359                    Clara Nunes no Zicartola, 1971.
# 92361                                              Essen
# 92362          Happy IV. Charles and his wife Queen Zita
#
#                                         PREfinal_caption  \
# 0                                            Albert Pike
# 1            Blount and her young daughter Ruth, in 1911
# 3      Brizola during his inauguration ceremony as go...
# 4                                             Buttisholz
# 7                    St. Louis Cathedral, Interior view,
# ...                                                  ...
# 92354                       Kwun Tong Magistrates' Court
# 92355              Haida Heritage Centre at Kay Llnagaay
# 92359                    Clara Nunes no Zicartola, 1971.
# 92361                                              Essen
# 92362          Happy IV. Charles and his wife Queen Zita
#
#       page_title_translation                   final_page_title  \
# 0                                                   Albert Pike
# 1                                                   Anna Blount
# 3                                                Leonel Brizola
# 4                                                    Buttisholz
# 7                             St. Louis Cathedral (New Orleans)
# ...                      ...                                ...
# 92354                            Magistrates' court (Hong Kong)
# 92355                                     Haida Heritage Centre
# 92359                                                 Zicartola
# 92361                                             Essen (Haren)
# 92362      József Mindszenty                  József Mindszenty
#
#                      PREfinal_page_title
# 0                            Albert Pike
# 1                            Anna Blount
# 3                         Leonel Brizola
# 4                             Buttisholz
# 7      St. Louis Cathedral (New Orleans)
# ...                                  ...
# 92354     Magistrates' court (Hong Kong)
# 92355              Haida Heritage Centre
# 92359                          Zicartola
# 92361                      Essen (Haren)
# 92362                  József Mindszenty
#
# [46183 rows x 22 columns]

# %%
model = AutoModelForTokenClassification.from_pretrained("dbmdz/bert-large-cased-finetuned-conll03-english")
tokenizer = AutoTokenizer.from_pretrained("bert-base-cased")

label_list = [
    "O",       # Outside of a named entity
    "B-MISC",  # Beginning of a miscellaneous entity right after another miscellaneous entity
    "I-MISC",  # Miscellaneous entity
    "B-PER",   # Beginning of a person's name right after another person's name
    "I-PER",   # Person's name
    "B-ORG",   # Beginning of an organisation right after another organisation
    "I-ORG",   # Organisation
    "B-LOC",   # Beginning of a location right after another location
    "I-LOC"    # Location
]
# Out:
# Downloading:   0%|          | 0.00/998 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/213k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/436k [00:00<?, ?B/s]

# %%
def retrieve_entities(pairs, verbose=False):
    def repair(s):
        return s.replace(' #', '').replace('#', '')
    def unique(l):
        return list(set(l))
    
    
    reading_entity = False
    current_entity_type = None
    
    misc, per, org, loc = [], [], [], []
    
    entity_parts = []
    
    for part, et in pairs:
        if not reading_entity and et == 'O':
            continue
        else:
            if not reading_entity:
                current_et = et
                reading_entity = True               
                
            if current_et == et:
                entity_parts.append(part)
            else:
                repaired_entity = repair(' '.join(entity_parts))
                
                if verbose:
                    print(repaired_entity)
                    
                locals()[current_et.split('-')[-1].lower()].append(repaired_entity)
                entity_parts.clear()
                
                if et == 'O':
                    reading_entity = False
                    current_et = None
                else:
                    entity_parts.append(part)
                    current_et = 'I-' + et.split('-')[-1]
                    
                    
    return { 'misc': unique(misc), 'per': unique(per), 'org': unique(org), 'loc': unique(loc)}

# %%
image_entities = { }

for index, row in matchings.iterrows():
    try:
        sequence = row['page_title'].strip()
        
        if sequence != '':
            tokens = tokenizer.tokenize(tokenizer.decode(tokenizer.encode(sequence)))
            inputs = tokenizer.encode(sequence, return_tensors="pt")

            outputs = model(inputs)[0]
            predictions = torch.argmax(outputs, dim=2)

            l = [(token, label_list[prediction]) for token, prediction in zip(tokens, predictions[0].tolist())]

            image_entities[index] = retrieve_entities(l)
    except Exception as ex:
        print(index, sequence)
        print(str(ex))
        print()

# %%
with open('page_title_lang_entities.dump', 'wb') as file:
    cloudpickle.dump(image_entities, file)
