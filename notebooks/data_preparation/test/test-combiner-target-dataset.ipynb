# %%
# !pip install rapidfuzz -qq

# %%
import numpy as np
import pandas as pd
from rapidfuzz import fuzz

# %%
matchings = pd.read_csv('../input/test-dataset/test-matchings.csv', keep_default_na=False)
matchings['target_id'] = matchings.index

matchings.rename(columns={ 'title_translit': 'page_title_translit' }, inplace=True)

# %% [markdown]
# ## Translation Combiner
#
# ### Caption Translation

# %%
# %%time

matchings['caption_translation'] = ''

for i in range(6):
    part = pd.read_csv('../input/test-trans-caption-{0}-6/tran_title_0{1}.csv'.format(i + 1, i), keep_default_na=False)
    part['caption_translation'] = part['caption_translation'].str.strip()
    indices = part[(part['caption_translation'] != '')].index
    matchings.loc[indices, 'caption_translation'] = part.loc[indices, 'caption_translation']
# Out:
# CPU times: user 5.03 s, sys: 520 ms, total: 5.55 s
# Wall time: 7.32 s

# %%
def CollectFinalColumn(field, source_column):
    final_field = 'final_' + field
    field_lang = field + '_lang'
    field_translit = field + '_translit'
    field_translation = field + '_translation'
        
    matchings[final_field] = matchings[field_translation]

    mask = (matchings[field_lang] == 'en') & (matchings[final_field] == '')
    matchings.loc[mask, final_field] = matchings.loc[mask, source_column]

    condition = (matchings[field_lang] != 'en') & (matchings[final_field] == '') & (matchings[field_translit] != '')
    matchings.loc[condition, final_field] = matchings.loc[condition, field_translit]
    
    PREfinal_field = 'PREfinal_' + field
    matchings[PREfinal_field] = matchings[field_translation]
    empty_indices = matchings[(matchings[PREfinal_field] == '') & (matchings[source_column] != '')].index
    matchings.loc[empty_indices, PREfinal_field] = matchings.loc[empty_indices, source_column]

# %%
CollectFinalColumn('caption', 'caption_reference_description')

# %%
matchings[(matchings['final_caption'] == '')]
# Out:
#                                             page_title  \
# 3021                                Αέτωμα της Λέαινας
# 9114                                       داوید لوییس
# 21059     North Carolina's 12th congressional district
# 27712                    এশিয়ান ইউনিভার্সিটি ফর উইমেন
# 29281      North Carolina's 7th congressional district
# 30692                                   Daerah Halland
# 32487                             Mahajana Law College
# 33731                                   Sofiane Harkat
# 40098                     Schifffahrtsmuseum Stavanger
# 45105                                 Mercedes Menafra
# 58846                                Riosucio (Caldas)
# 59504                                        ロイ・ハーグローヴ
# 62241  Ærestegn for Fortjenester af Republikken Østrig
# 86756                                      روبرتو ماتا
#
#       caption_reference_description  \
# 3021
# 9114                           2015
# 21059                     2013–2017
# 27712                          ২০১২
# 29281                     2013–2017
# 30692
# 32487                           [1]
# 33731                          2006
# 40098                          2010
# 45105                          2005
# 58846                          [4]​
# 59504                          2008
# 62241                   15. 16. 17.
# 86756                          ۱۹۶۰
#
#                                      page_title_translit caption_translit  \
# 3021                                  Aetoma tis Leainas
# 9114
# 21059
# 27712
# 29281
# 30692
# 32487
# 33731
# 40098
# 45105
# 58846
# 59504
# 62241  Aerestegn for Fortjenester af Republikken Oestrig
# 86756
#
#       page_title_lang  page_title_lang_p  page_title_en caption_lang  \
# 3021               el           0.997957          False           en
# 9114               fa           0.965861          False           fr
# 21059              en           0.817512           True           de
# 27712              bn           0.664426          False           bn
# 29281              en           0.846864           True           de
# 30692              ms           0.923291          False           en
# 32487              en           0.547605           True           sh
# 33731              fr           0.357885          False           fr
# 40098              de           0.760745          False           fr
# 45105              en           0.152145           True           fr
# 58846              es           0.344780          False           jv
# 59504              ja           0.992550          False           fr
# 62241              da           0.707905          False           cs
# 86756              fa           0.482039          False           fa
#
#        caption_lang_p  caption_en  caption_contains_digit undigit_caption  \
# 3021         0.124504        True                   False
# 9114         0.361018       False                    True
# 21059        0.580778       False                    True               –
# 27712        0.982708       False                    True
# 29281        0.580778       False                    True               –
# 30692        0.124504        True                   False
# 32487        0.395106       False                    True              []
# 33731        0.241057       False                    True
# 40098        0.237198       False                    True
# 45105        0.332307       False                    True
# 58846        0.191414       False                    True             []​
# 59504        0.290807       False                    True
# 62241        0.391773       False                    True           . . .
# 86756        0.999189       False                    True
#
#        page_title_contains_digit  \
# 3021                       False
# 9114                       False
# 21059                       True
# 27712                      False
# 29281                       True
# 30692                      False
# 32487                      False
# 33731                      False
# 40098                      False
# 45105                      False
# 58846                      False
# 59504                      False
# 62241                      False
# 86756                      False
#
#                                     undigit_page_title  \
# 3021                                Αέτωμα της Λέαινας
# 9114                                       داوید لوییس
# 21059       North Carolina's th congressional district
# 27712                    এশিয়ান ইউনিভার্সিটি ফর উইমেন
# 29281       North Carolina's th congressional district
# 30692                                   Daerah Halland
# 32487                             Mahajana Law College
# 33731                                   Sofiane Harkat
# 40098                     Schifffahrtsmuseum Stavanger
# 45105                                 Mercedes Menafra
# 58846                                Riosucio (Caldas)
# 59504                                        ロイ・ハーグローヴ
# 62241  Ærestegn for Fortjenester af Republikken Østrig
# 86756                                      روبرتو ماتا
#
#                                                   target  target_id  \
# 3021                          Αέτωμα της Λέαινας [SEP]         3021
# 9114                              داوید لوییس [SEP] 2015       9114
# 21059  North Carolina's 12th congressional district [...      21059
# 27712           এশিয়ান ইউনিভার্সিটি ফর উইমেন [SEP] ২০১২      27712
# 29281  North Carolina's 7th congressional district [S...      29281
# 30692                             Daerah Halland [SEP]        30692
# 32487                     Mahajana Law College [SEP] [1]      32487
# 33731                          Sofiane Harkat [SEP] 2006      33731
# 40098            Schifffahrtsmuseum Stavanger [SEP] 2010      40098
# 45105                        Mercedes Menafra [SEP] 2005      45105
# 58846                       Riosucio (Caldas) [SEP] [4]​      58846
# 59504                               ロイ・ハーグローヴ [SEP] 2008      59504
# 62241  Ærestegn for Fortjenester af Republikken Østri...      62241
# 86756                             روبرتو ماتا [SEP] ۱۹۶۰      86756
#
#       caption_translation final_caption PREfinal_caption
# 3021
# 9114                                                2015
# 21059                                          2013–2017
# 27712                                               ২০১২
# 29281                                          2013–2017
# 30692
# 32487                                                [1]
# 33731                                               2006
# 40098                                               2010
# 45105                                               2005
# 58846                                               [4]​
# 59504                                               2008
# 62241                                        15. 16. 17.
# 86756                                               ۱۹۶۰

# %% [markdown]
# ### Page Title Translation

# %%
matchings['page_title_translation'] = ''

for i in range(6):
    part = pd.read_csv('../input/test-trans-page-title-{0}-6/tran_title_0{1}.csv'.format(i + 1, i), keep_default_na=False)
    part['page_title_translation'] = part['page_title_translation'].str.strip()
    indices = part[(part['page_title_translation'] != '')].index
    matchings.loc[indices, 'page_title_translation'] = part.loc[indices, 'page_title_translation']

# %%
CollectFinalColumn('page_title', 'page_title')

# %%
matchings[matchings['final_page_title'] == '']
# Out:
#        page_title                      caption_reference_description  \
# 25624  Alain Menu  Alain Menu pilotando su Renault Laguna de 1997...
#
#       page_title_translit caption_translit page_title_lang  page_title_lang_p  \
# 25624                                                   eo           0.240302
#
#        page_title_en caption_lang  caption_lang_p  caption_en  ...  \
# 25624          False           es        0.737402       False  ...
#
#        page_title_contains_digit undigit_page_title  \
# 25624                      False         Alain Menu
#
#                                                   target target_id  \
# 25624  Alain Menu [SEP] Alain Menu pilotando su Renau...     25624
#
#                                      caption_translation  \
# 25624  Alain Menu driving his Renault Laguna de at th...
#
#                                            final_caption  \
# 25624  Alain Menu driving his Renault Laguna de at th...
#
#                                         PREfinal_caption  \
# 25624  Alain Menu driving his Renault Laguna de at th...
#
#       page_title_translation final_page_title PREfinal_page_title
# 25624                                                  Alain Menu
#
# [1 rows x 22 columns]

# %%
matchings.columns
# Out:
# Index(['page_title', 'caption_reference_description', 'page_title_translit',
#        'caption_translit', 'page_title_lang', 'page_title_lang_p',
#        'page_title_en', 'caption_lang', 'caption_lang_p', 'caption_en',
#        'caption_contains_digit', 'undigit_caption',
#        'page_title_contains_digit', 'undigit_page_title', 'target',
#        'target_id', 'caption_translation', 'final_caption', 'PREfinal_caption',
#        'page_title_translation', 'final_page_title', 'PREfinal_page_title'],
#       dtype='object')

# %%
fields = ['caption_reference_description', 'page_title', 'page_title_translit', 'caption_translit', \
          'final_caption', 'PREfinal_caption', 'PREfinal_page_title', 'final_page_title', \
          'caption_translation', 'page_title_translation']

for field in fields:
    matchings[field] = matchings[field].str.replace(r'\s{2,}', ' ', regex=True)

# %%
matchings.to_csv('final_matchings.csv', index=False)

# %%
matchings
# Out:
#                     page_title  \
# 0                  Albert Pike
# 1                  Anna Blount
# 2                  Río Marañón
# 3               Leonel Brizola
# 4                   Buttisholz
# ...                        ...
# 92361            Essen (Haren)
# 92362        Mindszenty József
# 92363             Пещеры Крыма
# 92364            MOWAG Piranha
# 92365  Plav (České Budějovice)
#
#                            caption_reference_description  \
# 0                                            Albert Pike
# 1            Blount and her young daughter Ruth, in 1911
# 2            Die Río Marañón in die Huánuco-streek, Peru
# 3      Brizola during his inauguration ceremony as go...
# 4                                             Buttisholz
# ...                                                  ...
# 92361                                              Essen
# 92362        Boldog IV. Károly és felesége Zita királyné
# 92363                 Вход в пещеру Суук-Коба (Холодная)
# 92364                     Usuaris del Piranha 5 en blau.
# 92365                                             Escudo
#
#            page_title_translit                             caption_translit  \
# 0
# 1
# 2                  Rio Maranon  Die Rio Maranon in die Huanuco-streek, Peru
# 3
# 4
# ...                        ...                                          ...
# 92361
# 92362        Mindszenty Jozsef  Boldog IV. Karoly es felesege Zita kiralyne
# 92363           Peschery Kryma        Vhod v pescheru Suuk-Koba (Holodnaja)
# 92364
# 92365  Plav (Česke Budějovice)
#
#       page_title_lang  page_title_lang_p  page_title_en caption_lang  \
# 0                  en           0.124504           True           en
# 1                  en           0.739186           True           en
# 2                  es           0.684134          False           de
# 3                  en           0.361589           True           en
# 4                  en           0.346513           True           en
# ...               ...                ...            ...          ...
# 92361              en           0.290392           True           en
# 92362              de           0.358293          False           hu
# 92363              ru           0.931901          False           ru
# 92364              pt           0.832627          False           es
# 92365              cs           0.624523          False           es
#
#        caption_lang_p  caption_en  ...  page_title_contains_digit  \
# 0            0.124504        True  ...                      False
# 1            0.971129        True  ...                      False
# 2            0.376005       False  ...                      False
# 3            0.997266        True  ...                      False
# 4            0.346513        True  ...                      False
# ...               ...         ...  ...                        ...
# 92361        0.124504        True  ...                      False
# 92362        0.987040       False  ...                      False
# 92363        0.973208       False  ...                      False
# 92364        0.643328       False  ...                      False
# 92365        0.309417       False  ...                      False
#
#             undigit_page_title  \
# 0                  Albert Pike
# 1                  Anna Blount
# 2                  Río Marañón
# 3               Leonel Brizola
# 4                   Buttisholz
# ...                        ...
# 92361            Essen (Haren)
# 92362        Mindszenty József
# 92363             Пещеры Крыма
# 92364            MOWAG Piranha
# 92365  Plav (České Budějovice)
#
#                                                   target target_id  \
# 0                          Albert Pike [SEP] Albert Pike         0
# 1      Anna Blount [SEP] Blount and her young daughte...         1
# 2      Río Marañón [SEP] Die Río Marañón in die Huánu...         2
# 3      Leonel Brizola [SEP] Brizola during his inaugu...         3
# 4                            Buttisholz [SEP] Buttisholz         4
# ...                                                  ...       ...
# 92361                          Essen (Haren) [SEP] Essen     92361
# 92362  Mindszenty József [SEP] Boldog IV. Károly és f...     92362
# 92363  Пещеры Крыма [SEP] Вход в пещеру Суук-Коба (Хо...     92363
# 92364  MOWAG Piranha [SEP] Usuaris del Piranha 5 en b...     92364
# 92365               Plav (České Budějovice) [SEP] Escudo     92365
#
#                                caption_translation  \
# 0
# 1
# 2      Die Río Marañón in die Huánuco-streek, Peru
# 3
# 4
# ...                                            ...
# 92361
# 92362    Happy IV. Charles and his wife Queen Zita
# 92363        Entrance to the Suuk-Koba cave (Cold)
# 92364                       Piranha users in blue.
# 92365                                       Shield
#
#                                            final_caption  \
# 0                                            Albert Pike
# 1            Blount and her young daughter Ruth, in 1911
# 2            Die Río Marañón in die Huánuco-streek, Peru
# 3      Brizola during his inauguration ceremony as go...
# 4                                             Buttisholz
# ...                                                  ...
# 92361                                              Essen
# 92362          Happy IV. Charles and his wife Queen Zita
# 92363              Entrance to the Suuk-Koba cave (Cold)
# 92364                             Piranha users in blue.
# 92365                                             Shield
#
#                                         PREfinal_caption  \
# 0                                            Albert Pike
# 1            Blount and her young daughter Ruth, in 1911
# 2            Die Río Marañón in die Huánuco-streek, Peru
# 3      Brizola during his inauguration ceremony as go...
# 4                                             Buttisholz
# ...                                                  ...
# 92361                                              Essen
# 92362          Happy IV. Charles and his wife Queen Zita
# 92363              Entrance to the Suuk-Koba cave (Cold)
# 92364                             Piranha users in blue.
# 92365                                             Shield
#
#         page_title_translation         final_page_title  \
# 0                                           Albert Pike
# 1                                           Anna Blount
# 2                Marañón River            Marañón River
# 3                                        Leonel Brizola
# 4                                            Buttisholz
# ...                        ...                      ...
# 92361                                     Essen (Haren)
# 92362        József Mindszenty        József Mindszenty
# 92363             Crimea caves             Crimea caves
# 92364            MOWAG Piranha            MOWAG Piranha
# 92365  Plav (České Budějovice)  Plav (České Budějovice)
#
#            PREfinal_page_title
# 0                  Albert Pike
# 1                  Anna Blount
# 2                Marañón River
# 3               Leonel Brizola
# 4                   Buttisholz
# ...                        ...
# 92361            Essen (Haren)
# 92362        József Mindszenty
# 92363             Crimea caves
# 92364            MOWAG Piranha
# 92365  Plav (České Budějovice)
#
# [92366 rows x 22 columns]
